# %% [markdown]
# # Week 2.2 Lab: GitHub + Colab + GCP Integration

# %% [markdown]
# In this guided lab, you will practice setting up your **team workflow** by connecting GitHub, Google Colab, Google Drive,
# and Google Cloud Platform (GCP). By the end, you will have a working notebook saved in your team repo and authenticated to GCP.
#
# **Learning Objectives:**
# - Create and configure a GitHub account (if not already done).
# - Create or join your **team repository** on GitHub.
# - Connect Colab to Google Drive for data and notebook persistence.
# - Authenticate Colab to access GCP services (BigQuery, Storage).
# - Save your Colab notebook to your GitHub repository.

# %% [markdown]
# ## 1. GitHub Account & Team Repository

# %% [markdown]
# 1. Go to [https://github.com](https://github.com) and create an account (if you don’t already have one).
# 2. One teammate should create a new repository (e.g., `MGMT467_TeamX`), set it to **Private**, and add collaborators.
# 3. Each team member should **accept the invite** to the repo.
# 4. Confirm by cloning the repo locally or simply viewing it online.
#
# :bulb: Later labs will rely on this shared repo for collaboration.

# %% [markdown]
# ## 2. Connect Colab to Google Drive

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Check contents (optional)
# !ls /content/drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '1)hola.gdoc'
# '201 exam 1,2.gdoc'
#  295.gdoc
# '295 project.gdoc'
# '335 MIDTERM 2.gdoc'
# '361 exam 1.gdoc'
#  Accounting.gdoc
# 'assigment 11.gdoc'
# 'assignment 05.gdoc'
# 'assignment 1'
# 'Assignment 22.gdoc'
# 'Assignment -6 .gdoc'
# 'assignment 7.gdoc'
#  astr.gdoc
#  astronomy.gdoc
# 'astro rec.gdoc'
# 'asu essay 1.gdoc'
# 'asu essay 2 optional.gdoc'
# 'Ayushnab injury.gdoc'
# 'Both the lecture and the passage mainly discussed working four days in a week.gdoc'
# 'Both the reading  passage and the lecture mainly discuss if people can live on mars.gdoc'
# 'Both the reading passage and the lecture mainly discuss the benefits of avocados .gdoc'
# 'Both the reading passage and the lecture mainly discuss who settled in New Zealand first.gdoc'
# 'Calling Bullshit Reflection.gdoc'
# 'case competition reflection.gdoc'
# 'Checking Bias Activity.gdoc'
# 'Chinese 43 independent part.gdoc'
# ' Chines toefl 18.gdoc'
# 'CM 10000- Estimating Activity.gdoc'
#  Cm100.gdoc
# 'CM Assignment 16.gdoc'
# 'CM final project.gdoc'
# 'Coalition essay.gdoc'
#  codes_python.gdoc
#  codes.sql.gdoc
# 'Colab Notebooks'
# 'Colorado University Boulder.gdoc'
# 'COM 250 Notes.gdoc'
# 'Concentration Paper.gdoc'
# 'Construction management .gdoc'
# 'Copy of Milestone 3 MGMT544.docx'
# 'Copy of Milestone 3 MGMT544.gdoc'
# 'Copy of Official Real Tests Book (1).pdf'
# 'Copy of Official Real Tests Book (2).pdf'
# 'Copy of Official Real Tests Book (3).pdf'
# 'Copy of Official Real Tests Book.pdf'
# 'Copy of scla project papaer.gdoc'
# 'Copy of Toefl speaking structures .docx'
# 'Cover letter .gdoc'
#  cs.gdoc
# 'CSU boulder.gdoc'
# 'CU boulder.gdoc'
# 'custom regulations .gdoc'
# 'Data Documentation_7.gdoc'
# 'Data Documentation_8.gdoc'
# 'Data Documentation.gdoc'
# 'DATA DOCUMENTATION.gdoc'
# 'Data Documentation: KO vs PEP Total Return Analysis (July 2024 – July 2025).gdoc'
# 'Data Documentation – Portfolio Optimization (Session 6).gdoc'
# 'Data feminism response paper.gdoc'
# 'death be not proud essay.docx'
#  Document-untitled.pdf
# 'Duke - Motivatiion letter.gdoc'
#  duke_renewed.gdoc
# 'eaps exam.gdoc'
#  eaps.gdoc
#  EAPS.gdoc
#  EBSCO
# 'econ 252.gdoc'
# 'econ 370 exm2.gdoc'
# 'econ .gdoc'
# 'Econ .gdoc'
# 'econ micro.gdoc'
#  efcc509d-53ca-4d70-b624-e4e1604547ed.jpg
# 'essay 3 -usc.gdoc'
# 'Essay writing.gdoc'
# 'Ethical Dilemmas in Competitive Sports: Case Study 10.gdoc'
#  evaluation.gdoc
# 'exam 3 254 (1).gdoc'
# 'exam 3 254.gdoc'
# 'EXAM 4.gdoc'
# 'Final Plan of Study.gdoc'
# 'final project, with comments.ipynb'
# 'final tool.gdoc'
#  frt.gdoc
# 'Getting started.pdf'
#  gg.gdoc
#  GP2.gdoc
# 'group Challange  4.gdoc'
# 'Gurbanov, Kanan MGMT 335.005 Assigment 2.gdoc'
# 'Harvard MS in Data Science – Motivation Letter.gdoc'
# 'homeless cituation in us and worldwide.gslides'
#  hw_2_saunok.gdoc
#  hw_2_saunok.pdf
# 'HW 6.gdoc'
# 'Hyperlocal Trump Harris Election Results Dataset.gdoc'
#  IMG_0001.HEIC
#  IMG_0748.JPG
#  IMG_0749.JPG
#  IMG_0750.JPG
#  IMG_0751.JPG
#  IMG_0752.JPG
#  IMG_9997.HEIC
# 'Impactful Experience - USC.gdoc'
# 'in-class 21.gdoc'
# 'In-class 2.gdoc'
# 'Interview an Alumnus.gdoc'
# 'Job Fair Game Plan.gdoc'
# 'Kanan Gurbanov- CV.pdf'
#  Kanan_Gurbanov_GradSchool_GoalSummary_5.gdoc
# 'kenan example.gdoc'
# 'lab activity.gdoc'
#  Links_8.gdoc
# 'Links for Session 3.gdoc'
# 'Links for session 4.gdoc'
# 'Links Session 5.gdoc'
# 'Links Session 6.gdoc'
# 'Links Session 7.gdoc'
#  Madrid.gdoc
# 'Mgmt 150-250.docx'
# 'Mgmt 150-250.gdoc'
# 'mgmt 254 ex2.gdoc'
# 'mgmt 254 exam 2 material.gdoc'
# 'mgmt 254.gdoc'
# 'mgmt 295 alum.gdoc'
# 'MGMT 295.gdoc'
# 'Mgmt 335.gdoc'
# 'mgmt 335 mid 1.gdoc'
# 'mgmt 361.gdoc'
# 'mgmt 370 mid 1.gdoc'
# 'MGMT 388.gdoc'
#  MGMT467
#  Mgmt.gdoc
# 'midterm2 335.gdoc'
#  MIT.gdoc
# 'Motivation Letter – Arizona State University.gdoc'
# 'Motivation letter.gdoc'
# 'Motivation Letter – Leiden University.gdoc'
# 'Motivation Letter – Master’s in Business Data Science & Analytics MSU.gdoc'
# 'Motivation Letter – UCL.gdoc'
# 'Motivation Letter – University of Southern California.gdoc'
# 'Motivation Letter – University of Virginia.gdoc'
# 'Motivation Letter – University of Washington.gdoc'
# 'Motivation Letter – UT Austin McCombs School of Business.gdoc'
#  munich.gdoc
# 'OBHR 330 EXAM 1.gdoc'
# 'obhr asg 4.gdoc'
# 'obhr case 1 part 3 .gdoc'
# 'OBHR CH2.gdoc'
# 'OBHR CH3.gdoc'
# 'OBHR EX2.gdoc'
# 'obhr  project.gdoc'
# 'optional essay - usc.gdoc'
# 'outdoor lab 2.gdoc'
#  Outlook
# 'Penn State.gdoc'
# 'Penn State part 2.gdoc'
# 'Penn state task 1and 2.gdoc'
# 'personality types assignment.gdoc'
# 'Pitch Letter.gdoc'
# 'Presentation .gdoc'
# 'Privacy Concerns with Exhaust Data.gdoc'
# 'Project 2 .gdoc'
# 'Pros and Cons of Bottled Water.gslides'
#  Psychologist.gdoc
# 'Purdue university .gdoc'
# 'quiz 1 310.gdoc'
# 'RabiteBank recommendation.gdoc'
#  References.gdoc
# 'reflection 2.gdoc'
# 'REFLECTION PARAGRAPH (1).gdoc'
# 'REFLECTION PARAGRAPH (2).gdoc'
# 'Reflection Paragraph_7.gdoc'
# 'Reflection Paragraph_8.gdoc'
# 'Reflection Paragraph.gdoc'
# 'REFLECTION PARAGRAPH.gdoc'
# 'Reflection Paragraph_Session 5.gdoc'
# 'Reflection – Session 6 Portfolio Optimization.gdoc'
# 'reflection w4.gdoc'
# 'Reflection week 6.gdoc'
# 'Reflection week 7.gdoc'
# 'reflection week 8.gdoc'
#  Reply.gdoc
# 'REVIEW SAT.pdf'
# 'SAT 1 Final Review_Dec-1.pdf'
# 'school project.gdoc'
# 'Scla '
# 'scla 102 komey.gdoc'
#  Scla.gdoc
# 'scla project paper.gdoc'
#  Seoul.gdoc
# 'Session 1.gdoc'
# 'session 1 video links.gdoc'
# 'Session 2 – Custom Dividend Screener Data Documentation.gdoc'
# 'Session 2 Submission Links.gdoc'
# 'Session 3 - data documentation.gdoc'
# 'Short Essay 2.gdoc'
# 'Short essay - Antigone.gdoc'
# 'Solar energy provides energy.gdoc'
# 'Some people think that the government should spend money to support  artistic programs, while others think that the government should  use extra money to fund programs to improve the environment.docx'
# 'Some people think that the government should spend money to support  artistic programs, while others think that the government should  use extra money to fund programs to improve the environment.gdoc'
# 'Span 101.gdoc'
# 'span 101..gdoc'
# 'Span 102 project 3.gdoc'
# 'Standards  Assignment .gdoc'
# 'Stone building in mexico and they cant find how they used.gdoc'
# 'TEAM 04-10 - PART 1.gdoc'
# 'TEAM 04-10 - PART 2 .gdoc'
#  Tets.gdoc
# 'The Ultimate guide to SAT grammar.pdf.pdf'
# 'Toefl (1).gdoc'
# 'toefl essay 2.gdoc'
#  Toefl.gdoc
# 'Toefl speaking structures .docx'
# 'Toefl speaking structures .gdoc'
# 'Tokyo .gdoc'
# 'ucl perosnal statement.gdoc'
# 'University at Albany.gdoc'
# 'University- masters list.gsheet'
# 'University of Minnesota twin cities .gdoc'
# 'Untitled Diagram (1).drawio'
# 'Untitled Diagram (2).drawio'
# 'Untitled Diagram.drawio'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (26).gdoc'
# 'Untitled document (27).gdoc'
# 'Untitled document (28).gdoc'
# 'Untitled document (29).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (30).gdoc'
# 'Untitled document (31).gdoc'
# 'Untitled document (32).gdoc'
# 'Untitled document (33).gdoc'
# 'Untitled document (34).gdoc'
# 'Untitled document (35).gdoc'
# 'Untitled document (36).gdoc'
# 'Untitled document (37).gdoc'
# 'Untitled document (38).gdoc'
# 'Untitled document (39).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (40).gdoc'
# 'Untitled document (41).gdoc'
# 'Untitled document (42).gdoc'
# 'Untitled document (43).gdoc'
# 'Untitled document (44).gdoc'
# 'Untitled document (45).gdoc'
# 'Untitled document (46).gdoc'
# 'Untitled document (47).gdoc'
# 'Untitled document (48).gdoc'
# 'Untitled document (49).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (50).gdoc'
# 'Untitled document (51).gdoc'
# 'Untitled document (52).gdoc'
# 'Untitled document (53).gdoc'
# 'Untitled document (54).gdoc'
# 'Untitled document (55).gdoc'
# 'Untitled document (56).gdoc'
# 'Untitled document (57).gdoc'
# 'Untitled document (58).gdoc'
# 'Untitled document (59).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (60).gdoc'
# 'Untitled document (61).gdoc'
# 'Untitled document (62).gdoc'
# 'Untitled document (63).gdoc'
# 'Untitled document (64).gdoc'
# 'Untitled document (65).gdoc'
# 'Untitled document (66).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation.gslides'
# 'usc- essay 2.gdoc'
#  UT-Austin.gdoc
# 'ut austin mc combus  first essay_edited.gdoc'
# 'ut austin optional essay_edited.gdoc'
# 'UVA essay 1.gdoc'
# 'uva essay 2.gdoc'
# 'uva essay 3.gdoc'
# 'week 5 reflection.gdoc'
#  wrangling.gdoc

# %% [markdown]
# ## 3. Authenticate GCP in Colab

# %%
from google.colab import auth
auth.authenticate_user()

print("Authenticated to GCP successfully!")
# Out:
# Authenticated to GCP successfully!

# %% [markdown]
# Once authenticated, you can access BigQuery and other GCP services from this notebook.

# %% [markdown]
# ## 4. Run a BigQuery Sanity Query

# %%
from google.cloud import bigquery

# Create a BigQuery client
client = bigquery.Client(project="mgmt-467-471119")

# Simple test query: public dataset
query = "SELECT name, SUM(number) as total FROM `bigquery-public-data.usa_names.usa_1910_2013` GROUP BY name ORDER BY total DESC LIMIT 5"
results = client.query(query).to_dataframe()

results
# Out:
#       name    total
# 0    James  4942431
# 1     John  4834422
# 2   Robert  4718787
# 3  Michael  4297230
# 4  William  3822209

# %% [markdown]
# ## 5. Save Notebook to GitHub

# %% [markdown]
# To push from Colab to GitHub, you can use a **personal access token (PAT)**.
#
# **Steps:**
# 1. On GitHub, go to **Settings → Developer settings → Personal access tokens (classic)**.
# 2. Generate a token with `repo` permissions (set expiry to ~7 days for safety).
# 3. In Colab, use the snippet below to push your notebook back to GitHub.
#
# :warning: Do **NOT** hardcode tokens in notebooks. Use `getpass` to input securely.

# %%
import os
from getpass import getpass

# Enter your GitHub credentials
username = "qurbanovkenan77-tech
mg"
token = getpass("Token: ")
repo = "mgmt467-analytics-portfolio"  # e.g., MGMT467_TeamX
notebook_filename = "Week2_2_Git_Colab_GCP_Lab.ipynb"
notebook_path = "/content/drive/MyDrive/MGMT467/Labs/" + notebook_filename # Corrected path

# Set git credentials globally
# !git config --global user.name "{username}"
# !git config --global user.email "{username}@users.noreply.github.com"

# Clone the repo if it doesn't exist
if not os.path.exists(repo):
  # !git clone https://{username}:{token}@github.com/{username}/{repo}.git

# Change directory to the repo
# %cd {repo}

# Copy notebook into repo
# !cp "{notebook_path}" .

# Commit and push
# !git add . && git commit -m "Added Week 2.2 Lab notebook" && git push
# Out:
# Token: ··········
# /content/mgmt467-analytics-portfolio
# [main 335c102] Added Week 2.2 Lab notebook
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Week2_2_Git_Colab_GCP_Lab.ipynb (90%)
# remote: Permission to artemiichirkov2/mgmt467-analytics-portfolio.git denied to qurbanovkenan77-tech.
# fatal: unable to access 'https://github.com/artemiichirkov2/mgmt467-analytics-portfolio.git/': The requested URL returned error: 403

# %% [markdown]
# ## ✅ Exit Ticket

# %% [markdown]
# Before you leave, make sure you have:
# - [ ] Mounted Google Drive in Colab
# - [ ] Authenticated to GCP successfully
# - [ ] Run the BigQuery sanity check
# - [ ] Saved your notebook to your team GitHub repo
#
# Upload your GitHub repo link to Brightspace as proof of completion.
